# %%
import pandas as pd
import numpy as np
import os

# %%
# Note: Download and copy dataset xlsx file to data folder since repository would not include it.
# Ensuring different operating systems could parse filepath properly

current_dir = os.path.abspath('')
parent_dir = os.path.dirname(current_dir)
# data_dir = os.path.join(parent_dir, 'data')
# dataset_dir = os.path.join(data_dir, 'file.xlsx')
print(current_dir)
# Out:
# c:\Users\jrdor\OneDrive\Desktop\LT2_DMW_Kmeans_shopping

# %%
columns = ['CustomerID', 'Gender', 'Location', 'Tenure_Months', 'Transaction_ID',
           'Transaction_Date', 'Product_SKU', 'Product_Description', 'Product_Category',
           'Quantity', 'Avg_Price', 'Delivery_Charges', 'Coupon_Status',
           'GST', 'Date', 'Offline_Spend', 'Month', 'Coupon_Code', 'Discount_pct']
shopping_data = pd.read_excel('data/file.xlsx', usecols=columns, parse_dates=['Transaction_Date', 'Date'])

# %%
# 
shopping_data.isna().sum()
# Out:
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %%
# drop na values for CustomerID
shopping_data.dropna(subset=['CustomerID'], inplace=True)

# %%
# verify na values if acceptable
shopping_data.isna().sum()
# Out:
# CustomerID               0
# Gender                   0
# Location                 0
# Tenure_Months            0
# Transaction_ID           0
# Transaction_Date         0
# Product_SKU              0
# Product_Description      0
# Product_Category         0
# Quantity                 0
# Avg_Price                0
# Delivery_Charges         0
# Coupon_Status            0
# GST                      0
# Date                     0
# Offline_Spend            0
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %%
shopping_data
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M     Chicago           12.0         16679.0
# 1         17850.0      M     Chicago           12.0         16680.0
# 2         17850.0      M     Chicago           12.0         16696.0
# 3         17850.0      M     Chicago           12.0         16699.0
# 4         17850.0      M     Chicago           12.0         16700.0
# ...           ...    ...         ...            ...             ...
# 52919     13155.0      F  California            8.0         22504.0
# 52920     18077.0      M     Chicago           34.0         24250.0
# 52921     16085.0      M  California           15.0         39991.0
# 52922     16085.0      M  California           15.0         39991.0
# 52923     13659.0      F     Chicago            8.0         39998.0
#
#       Transaction_Date     Product_SKU  \
# 0           2019-01-01  GGOENEBJ079499
# 1           2019-01-01  GGOENEBJ079499
# ...

# %%
# Info of categorical data
shopping_data.describe(exclude = [np.number, 'datetime64'])
# Out:
#        Gender Location     Product_SKU  \
# count   52924    52924           52924
# unique      2        5            1145
# top         F  Chicago  GGOENEBJ079499
# freq    33007    18380            3511
#
#                                       Product_Description Product_Category  \
# count                                               52924            52924
# unique                                                404               20
# top     Nest Learning Thermostat 3rd Gen-USA - Stainle...          Apparel
# freq                                                 3511            18126
#
#        Coupon_Status Coupon_Code
# count          52924       52524
# unique             3          45
# top          Clicked      SALE20
# freq           26926        6373

# %%
# View categoris
unique_product_categories = shopping_data['Product_Category'].unique()
print(unique_product_categories)
# Out:
# ['Nest-USA' 'Office' 'Apparel' 'Bags' 'Drinkware' 'Lifestyle' 'Waze'
#  'Headgear' 'Fun' 'Notebooks & Journals' 'Google' 'Nest-Canada' 'Bottles'
#  'Gift Cards' 'More Bags' 'Backpacks' 'Housewares' 'Android' 'Nest'
#  'Accessories']
